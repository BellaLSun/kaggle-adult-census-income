# %% [markdown]
# ### Imports

# %%
from prediction.loader import read_income_data
from prediction.loader import get_summary
from prediction.plot import scatter_plot
from prediction.plot import hexbin_plot
from prediction.plot import bar_plot
from prediction.plot import bar_percentage_plot

import matplotlib
#matplotlib.style.use('ggplot')
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (12.0, 8.0)

# %% [markdown]
# ### Load the data

# %%
df = read_income_data()
dfs = get_summary(df)

# %% [markdown]
# ### Global stats

# %%
dfs.columns_stats
# Out:
#                   age    workclass   fnlwgt education.num marital.status  \
# counts          32561        30725    32561         32561          32561
# uniques            73            8    21648            16              7
# missing             0         1836        0             0              0
# missing_perc       0%        5.64%       0%            0%             0%
# types         numeric  categorical  numeric       numeric    categorical
#
#                occupation relationship         race    sex hours.per.week  \
# counts              30718        32561        32561  32561          32561
# uniques                14            6            5      2             94
# missing              1843            0            0      0              0
# missing_perc        5.66%           0%           0%     0%             0%
# types         categorical  categorical  categorical   bool        numeric
#
#              native.country income native.continent is_single  capital  \
# ...

# %% [markdown]
# #### First, we observe some missing data on working data and native country

# %%
dfs['income']
# Out:
# "0.0" count      24720
# "0.0" perc      75.92%
# "1.0" count       7841
# "1.0" perc      24.08%
# counts           32561
# uniques              2
# missing              0
# missing_perc        0%
# types             bool
# Name: income, dtype: object

# %% [markdown]
# We notice that the income columns is imbalanced.

# %% [markdown]
# ### Scatter plot

# %%
plt.figure()
scatter_plot(df, "age", "education.num")
plt.show()

# %%
plt.figure()
scatter_plot(df, 'fnlwgt', 'capital.log')
plt.show()

# %%
plt.figure()
scatter_plot(df, 'age', 'capital.log')
plt.show()

# %%
plt.figure()
scatter_plot(df, 'fnlwgt', 'education.num')
plt.show()

# %% [markdown]
# #### These few scatters show us that a combination of some features could make a clean split of our dataset.

# %% [markdown]
# ### Bar plot

# %% [markdown]
# The next bar plots also describe our dataset and show some feature importance :
#
#  - Most people don't have capital gain or loss, but once they have more than 2^13 (8192) they are more likely to have more than 50k
#  - People who studies more have more chances to have more than 50k. They're also fewer.
#  - Single people mostly earn less than 50k

# %%
bar_plot(df, 'capital.log.round')
bar_percentage_plot(df, 'capital.log.round')
plt.show()

# %%
bar_plot(df, 'race')
bar_percentage_plot(df, 'race')
plt.show()

# %%
bar_plot(df, 'age')
bar_percentage_plot(df, 'age')
plt.show()

# %%
bar_plot(df, 'workclass')
bar_percentage_plot(df, 'workclass')
plt.show()

# %%
bar_plot(df, 'education.num')
bar_percentage_plot(df, 'education.num')
plt.show()

# %%
bar_plot(df, 'marital.status')
bar_percentage_plot(df, 'marital.status')
plt.show()

# %%
bar_plot(df, 'is_single')
bar_percentage_plot(df, 'is_single')
plt.show()

# %%
bar_plot(df, 'native.continent')
bar_percentage_plot(df, 'native.continent')
plt.show()

# %%
bar_plot(df, 'hours.per.week')
bar_percentage_plot(df, 'hours.per.week')
plt.show()

# %%
bar_plot(df, 'occupation')
bar_percentage_plot(df, 'occupation')
plt.show()
